# %% [markdown]
# # Vision Transformers (ViT)
# This notebook covers Vision Transformers, replacing traditional convolutions with self-attention for computer vision tasks.

# %%
import torch
import torch.nn as nn

# TODO: Implement Patch Embedding and Transformer Encoder for Images
