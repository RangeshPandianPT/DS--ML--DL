# %% [markdown]
# # Explainable AI (XAI) with Grad-CAM
# Visualizing what a Convolutional Neural Network is looking at using Gradient-weighted Class Activation Mapping (Grad-CAM).

# %%
import torch
import torchvision.models as models
import matplotlib.pyplot as plt

# TODO: Implement Grad-CAM hook on a pre-trained ResNet
