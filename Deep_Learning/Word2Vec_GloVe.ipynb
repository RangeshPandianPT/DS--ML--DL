# %% [markdown]
# # Word Embeddings: Word2Vec & GloVe
#
# Learn how words are represented as dense vectors before being fed into Neural Networks for NLP tasks. We will explore pre-trained embeddings and train our own using Gensim.

# %%
# !pip install gensim
import gensim
from gensim.models import Word2Vec
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
