# %% [markdown]
# # Time Series Forecasting with TCN
# Using Temporal Convolutional Networks and Transformers for sequential time series forecasting.

# %%
import torch
import torch.nn as nn

# TODO: Implement a 1D Dilated Convolutional layer for TCN
