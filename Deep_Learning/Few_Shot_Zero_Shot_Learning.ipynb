# %% [markdown]
# # Few-Shot and Zero-Shot Learning
# Techniques for allowing models to generalize to new tasks with very few or zero examples.

# %%
from transformers import pipeline

# TODO: Implement zero-shot classification using pre-trained models
