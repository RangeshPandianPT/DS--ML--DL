# %% [markdown]
# # Model Optimization: Quantization & Pruning
# Techniques to reduce model size and inference time using Quantization (e.g., INT8) and Pruning.

# %%
import torch
import torch.nn.utils.prune as prune

# TODO: Apply dynamic quantization and weight pruning to a model
