# %% [markdown]
# # Diffusion Models and DDPMs
# In this notebook, we explore Denoising Diffusion Probabilistic Models (DDPMs), the foundation behind modern image generation tools like Stable Diffusion.

# %%
import torch
import torch.nn as nn
import torchvision

# TODO: Implement a basic U-Net and Diffusion Process
