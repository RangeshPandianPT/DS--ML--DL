# %% [markdown]
# # Object Detection with YOLO
#
# In this notebook, we will explore Object Detection using pre-trained YOLO (You Only Look Once) models. Object detection identifies multiple objects within an image and their bounding boxes.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Note: You may need to install ultralytics for YOLOv8 (pip install ultralytics)
# from ultralytics import YOLO
