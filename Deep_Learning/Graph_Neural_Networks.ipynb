# %% [markdown]
# # Graph Neural Networks (GNN)
# Processing graph-structured data (like social networks or molecules) using PyTorch Geometric.

# %%
import torch
# import torch_geometric
# import torch_geometric.nn as geom_nn

# TODO: Define a simple GCN (Graph Convolutional Network)
