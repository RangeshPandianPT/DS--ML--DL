# %% [markdown]
# # Density-Based Spatial Clustering of Applications with Noise (DBSCAN)
#
# DBSCAN groups together points that are closely packed together (points with many nearby neighbors), marking as outliers points that lie alone in low-density regions (whose nearest neighbors are too far away).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans, DBSCAN

# %matplotlib inline

# %% [markdown]
# ## 1. The Problem with K-Means on Non-Spherical Data
# Let's generate data in the shape of two interleaving half circles (moons).

# %%
X, y = make_moons(n_samples=300, noise=0.05, random_state=42)
plt.scatter(X[:,0], X[:,1], s=50)
plt.title('Two Moons Dataset')
plt.show()

# %% [markdown]
# Let's see what K-Means does with this data.

# %%
kmeans = KMeans(n_clusters=2, random_state=42, n_init='auto')
y_kmeans = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=y_kmeans, cmap='viridis', s=50)
plt.title('K-Means on Two Moons (Fails to capture structure)')
plt.show()

# %% [markdown]
# ## 2. Enter DBSCAN
# DBSCAN can identify the arbitrary shapes of the clusters and separate them correctly.

# %%
dbscan = DBSCAN(eps=0.2, min_samples=5)
y_dbscan = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=y_dbscan, cmap='viridis', s=50)
plt.title('DBSCAN on Two Moons (Succeeds)')
plt.show()
