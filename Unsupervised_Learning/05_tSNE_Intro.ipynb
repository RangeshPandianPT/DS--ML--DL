# %% [markdown]
# # t-Distributed Stochastic Neighbor Embedding (t-SNE)
#
# t-SNE is a non-linear dimensionality reduction technique particularly well-suited for embedding high-dimensional data into a space of two or three dimensions, which can then be visualized in a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ## 1. Load Data
# We'll use the digits dataset, which contains 8x8 images of handwritten digits (64 dimensions).

# %%
digits = load_digits()
X = digits.data
y = digits.target
print(f'Original shape: {X.shape}')

# %% [markdown]
# ## 2. Apply t-SNE
# Let's reduce the 64 dimensions to 2. Note that t-SNE can be computationally expensive.

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)
print(f'Reduced shape: {X_tsne.shape}')

# %% [markdown]
# ## 3. Visualize
# t-SNE is excellent at creating clear separations between clusters in the low-dimensional space.

# %%
plt.figure(figsize=(10,8))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='tab10', alpha=0.7)
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('t-SNE 2D Projection of Digits')
plt.colorbar(scatter, ticks=range(10), label='Digit Class')
plt.show()
